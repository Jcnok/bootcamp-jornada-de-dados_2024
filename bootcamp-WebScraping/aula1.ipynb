# %% [markdown]
# # Aula 01
#
# # Resumo da Aula
#
# Nesta aula, abordamos técnicas de web scraping utilizando Python. Abaixo estão os principais tópicos discutidos:
#
# ## Tecnologias e Ferramentas Utilizadas
#
# - **Requests**: Biblioteca para fazer requisições HTTP.
# - **BeautifulSoup**: Biblioteca para parseamento de HTML e extração de dados.
# - **Pandas**: Biblioteca para manipulação e análise de dados.
#
# ## Passos Realizados
#
# 1. **Introdução ao Web Scraping**:
#     - Explicação sobre a importância de entender HTML e a estrutura das páginas web.
#     - Discussão sobre a ética e as implicações legais do web scraping.
# 2. **Configuração do Ambiente**:
#     - Criação de um projeto básico em Python.
#     - Instalação das bibliotecas necessárias (`requests`, `beautifulsoup4`, `pandas`).
# 3. **Primeira Requisição**:
#     - Realização de uma requisição simples para obter o IP da máquina.
#     - Explicação sobre o status code e a resposta da requisição.
# 4. **Extração de Dados do Mercado Livre**:
#     - Construção de uma URL de busca dinâmica.
#     - Parseamento do HTML retornado utilizando BeautifulSoup.
#     - Extração de informações específicas como título, preço, marca e link dos produtos.
#     - Armazenamento dos dados extraídos em um DataFrame do Pandas.
# 5. **Discussão sobre Técnicas Avançadas**:
#     - Introdução ao uso de ferramentas como Selenium e Puppeteer para automação de navegadores.
#     - Planejamento para futuras aulas, incluindo a criação de um objeto dinâmico para requisições paralelas e técnicas de login automatizado.

# %% [markdown]
# ## Exemplo de scraping:

# %% [markdown]
# * **Instalando as libs**:

# %%
# !poetry add bs4 pandas -q

# %% [markdown]
# * **Codigo exemplo:**

# %%
# Código de Exemplo
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de busca no Mercado Livre

url = "https://lista.mercadolivre.com.br/shampoo"

# Realiza a requisição

response = requests.get(url)

# Verifica se a requisição foi bem-sucedida

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    data = []
    # Encontra todos os produtos na página
    for item in soup.find_all('div', class_='ui-search-result__content'):
        title = item.find('h2', class_='ui-search-item__title').text.strip()
        price = item.find('span', class_='andes-money-amount ui-search-price__part ui-search-price__part--medium andes-money-amount--cents-superscript').text.strip()
        link = item.find('a', class_='ui-search-link')['href']
        data.append({'Título': title, 'Preço': price, 'Link': link})

    # Cria um DataFrame com os dados extraídos
    df = pd.DataFrame(data)
    display(df)

else:
    print("Erro na requisição")
# Out:
#                                                Título     Preço  \
# 0         Kit Shampoo E Condicionador Antiqueda Aq-01      R$79
# 1   Kit Shampoo + Máscara Matizadora Black Home Ca...   R$75,90
# 2        Doctar Plus Shampoo Anticaspa 240ml - Darrow   R$94,90
# 3   Shampoo Redutor De Grisalhos Grecin Control Gx...   R$63,82
# 4   Shampoo Anticaspa Men Ice Cool Menthol 400ml C...   R$22,90
# 5                     Keune Man Shampoo Fortify 250ml   R$71,99
# 6    Vichy Dercos Thechnique  Shampoo Antiqueda 400 g  R$118,73
# 7         Kit Zap Me Leva Black + Shampoo Detox 500ml   R$42,90
# 8   Shampoo Anticaspa Intensivo Dercos Cabelos Sec...   R$66,90
# 9   Shampoo Esfoliante Anticaspa Vichy Dercos Micr...   R$77,42
# 10  Shampoo E Condicionador Sos Hidratação Turbina...   R$48,99
# 11    Shampoo Calmante Dercos Sensi Scalp 200ml Vichy   R$81,97
# 12  Shampoo Tonalizante Color Change Castanho Escu...   R$29,52
# 13          Shampoo Lola Morte Súbita Hidratante 250g   R$16,69
# 14  Kit Shampoo + Condicionador Plástica Capilar I...   R$48,59
# 15  Shampoo Pantene Pro-v Brilho Extremo Frasco 400ml   R$18,35
# 16            Refil Shampoo Dercos Energy+ 200g Vichy   R$71,17
# 17            Dove Shampoo Recontrução Completa 670ml   R$25,67
# 18  Progressiva Liso Master Original Azul - Shampo...     R$309
# 19         Shampoo Bambu Nutre & Cresce Pantene 400ml   R$18,35
# 20           Shampoo Reconstrução Completa Dove 400ml   R$17,39
# 21  Shampoo Anticaspa Clear Limpeza Diária 2 Em 1 ...   R$23,12
# 22  Shampoo Cetoconazol Prevenção Anticaspa Coceir...   R$13,35
# 23               Shampoo Limpeza Profunda Clear 400ml   R$21,90
# 24   Kit Nioxin 2 Shampoo 300ml + Condicionador 300ml  R$250,80
# 25                              Shampoo Caspiol 100ml   R$15,93
# 26  Shampoo Anticaspa Intensivo La Roche-posay Ker...     R$117
# 27    Shampoo Recarga Natural Pureza Detox 325ml Seda    R$9,90
# 28  Shampoo Suave Hipoalergênico Antialérgico Aler...   R$64,20
# 29            Shampoo Multibenefícios 1 Litro Pantene   R$42,90
# 30  Kit Jubinha Infantil Shampoo Condicionador E C...  R$123,90
# 31  Truss Shampoo Therapy Controle De Oleosidade 3...      R$72
# 32  Truss Professional Equilibrium Shampoo & Condi...  R$163,78
# 33  Shampoo L'oréal Paris Elseve Glycolic Gloss 400ml   R$22,77
# 34  Shampoo Cazi Caspacil Xampu De 100ml De 100g C...   R$49,52
# 35        Shampoo Loreal Professionnel Silver - 300ml      R$70
# 36  Kit Ultra Soft Shampoo 1l E Máscara Pós Químic...  R$129,90
# 37  Shampoo Purificante Dercos Oil Correction 300g...   R$79,32
# 38  Kit Silver Touch - Shampoo + Condicionador Viz...     R$138
# 39  Farmaervas Shampoo Antiqueda Jaborandi E Vitam...   R$29,17
# 40                  Vichy Dercos Shampoo Energy+ 200g   R$83,25
# 41        Shampoo Anticoceira 650 Ml Head & Shoulders   R$30,74
# 42  Kit Linha A Aneethun Shampoo Creme Mascara + E...  R$251,99
# 43  Redken All Soft  Shampoo - 1000ml New Look Vol...  R$168,90
# 44  Kit x2 Shampoo Cetoconazol Prevenção Anticaspa...   R$33,12
# 45  La Roche-posay Kerium Shampoo 200ml 200g com 1...  R$106,48
# 46  Tio Nacho Kit Engrossador Shampoo 415ml +condi...   R$45,96
# 47  Kit Ultra Hydration Plus Shampoo + Condicionad...     R$172
#
#                                                  Link
# 0   https://www.mercadolivre.com.br/kit-shampoo-e-...
# 1   https://www.mercadolivre.com.br/kit-shampoo-ma...
# 2   https://www.mercadolivre.com.br/doctar-plus-sh...
# 3   https://www.mercadolivre.com.br/shampoo-reduto...
# 4   https://www.mercadolivre.com.br/shampoo-antica...
# 5   https://www.mercadolivre.com.br/keune-man-sham...
# 6   https://www.mercadolivre.com.br/vichy-dercos-t...
# 7   https://www.mercadolivre.com.br/kit-zap-me-lev...
# 8   https://www.mercadolivre.com.br/shampoo-antica...
# 9   https://www.mercadolivre.com.br/shampoo-esfoli...
# 10  https://www.mercadolivre.com.br/shampoo-e-cond...
# 11  https://www.mercadolivre.com.br/shampoo-calman...
# 12  https://www.mercadolivre.com.br/shampoo-tonali...
# 13  https://www.mercadolivre.com.br/shampoo-lola-m...
# 14  https://www.mercadolivre.com.br/kit-shampoo-co...
# 15  https://www.mercadolivre.com.br/shampoo-panten...
# 16  https://www.mercadolivre.com.br/refil-shampoo-...
# 17  https://www.mercadolivre.com.br/dove-shampoo-r...
# 18  https://www.mercadolivre.com.br/progressiva-li...
# 19  https://www.mercadolivre.com.br/shampoo-bambu-...
# 20  https://www.mercadolivre.com.br/shampoo-recons...
# 21  https://www.mercadolivre.com.br/shampoo-antica...
# 22  https://www.mercadolivre.com.br/shampoo-cetoco...
# 23  https://www.mercadolivre.com.br/shampoo-limpez...
# 24  https://www.mercadolivre.com.br/kit-nioxin-2-s...
# 25  https://www.mercadolivre.com.br/shampoo-caspio...
# 26  https://www.mercadolivre.com.br/shampoo-antica...
# 27  https://www.mercadolivre.com.br/shampoo-recarg...
# 28  https://www.mercadolivre.com.br/shampoo-suave-...
# 29  https://www.mercadolivre.com.br/shampoo-multib...
# 30  https://www.mercadolivre.com.br/kit-jubinha-in...
# 31  https://www.mercadolivre.com.br/truss-shampoo-...
# 32  https://www.mercadolivre.com.br/truss-professi...
# 33  https://www.mercadolivre.com.br/shampoo-loreal...
# 34  https://www.mercadolivre.com.br/shampoo-cazi-c...
# 35  https://www.mercadolivre.com.br/shampoo-loreal...
# 36  https://www.mercadolivre.com.br/kit-ultra-soft...
# 37  https://www.mercadolivre.com.br/shampoo-purifi...
# 38  https://www.mercadolivre.com.br/kit-silver-tou...
# 39  https://www.mercadolivre.com.br/farmaervas-sha...
# 40  https://www.mercadolivre.com.br/vichy-dercos-s...
# 41  https://www.mercadolivre.com.br/shampoo-antico...
# 42  https://www.mercadolivre.com.br/kit-linha-a-an...
# 43  https://www.mercadolivre.com.br/redken-all-sof...
# 44  https://www.mercadolivre.com.br/kit-x2-shampoo...
# 45  https://www.mercadolivre.com.br/la-roche-posay...
# 46  https://www.mercadolivre.com.br/tio-nacho-kit-...
# 47  https://www.mercadolivre.com.br/kit-ultra-hydr...

# %% [markdown]
# ## Próximos Passos
# - Transformar a classe de scraping em um objeto dinâmico.
# - Implementar requisições paralelas.
# - Explorar técnicas de automação de navegadores e login automatizado.
#
# ## Conclusão
# A aula forneceu uma base sólida para iniciar com web scraping em Python, utilizando bibliotecas populares e abordando tanto aspectos técnicos quanto éticos da prática.
